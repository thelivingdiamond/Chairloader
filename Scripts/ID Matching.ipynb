# %%
import os
import xml.etree.ElementTree as ET

# Set the input file path
input_file_path = 'id_name_files.txt'

# Create the root element of the output XML file
root = ET.Element('VariableLibrary')

# Read the input file line by line
with open(input_file_path) as input_file:
    for line in input_file:
        # Remove the newline character at the end of the line
        line = line.strip()

        # remove the quotes at the beginning and end of the line
        line = line[1:-1]

        # if the file doesn't end in .xml, skip it
        if not line.endswith('.xml'):
            continue

        # replace \\ with / in the line
        line = line.replace('\\\\', '/')
        
        # Create a new element for the current line
        element = ET.Element('IDFile')
        
        # Set the 'path' attribute to the current line
        element.set('path', line)
        
        # Set the other attributes to empty strings
        element.set('nameAttribute', '')
        element.set('idAttribute', '')
        element.set('variablePath', '')
        element.set('xmlPath', '')
        # Append the new element to the root element
        root.append(element)

# Create an ElementTree object with the root element
tree = ET.ElementTree(root)

# Write the ElementTree object to an output XML file
output_file_path = 'VariableLibrary.xml'
tree.write(output_file_path, xml_declaration=True, encoding='UTF-8', method='xml')

# %%
import xml.etree.ElementTree as ET

import xml.dom.minidom

def format_xml_file(file_path):
    # Read the file
    with open(file_path, 'r') as f:
        xml_str = f.read()

    # Parse the XML string
    dom = xml.dom.minidom.parseString(xml_str)

    # Format the attributes
    for node in dom.getElementsByTagName('*'):
        for attr_name, attr_value in node.attributes.items():
            # Create a new line before each attribute
            node.setAttribute('\n    ' + attr_name, attr_value)

    # Return the formatted XML string
    return dom.toprettyxml(indent='    ')


def format_xml(xml_string):
    root = ET.fromstring(xml_string)
    indent = 0
    formatted_xml = ""

    def indent_string():
        return "  " * indent

    def format_element(element):
        nonlocal indent, formatted_xml
        formatted_xml += f"{indent_string()}<{element.tag}"
        if element.attrib:
            for attr, value in element.attrib.items():
                formatted_xml += f" {attr}=\"{value}\""
        formatted_xml += ">\n"
        if element.text and element.text.strip():
            formatted_xml += f"{indent_string()}{element.text.strip()}\n"
        if len(element) > 0:
            indent += 1
            for child in element:
                format_element(child)
            indent -= 1
            formatted_xml += f"{indent_string()}</{element.tag}>\n"
        else:
            formatted_xml = formatted_xml.rstrip()
            formatted_xml += f"</{element.tag}>\n"

    format_element(root)
    return formatted_xml

def format_xml_with_attributes_on_newline(xml_file):
    # Parse the XML file
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Iterate through all elements in the tree
    for elem in tree.iter():
        # If the element has attributes, format them on separate lines
        if elem.attrib:
            elem_str = ET.tostring(elem, encoding='unicode')
            lines = elem_str.splitlines()
            # Remove the closing tag from the first line
            lines[0] = lines[0][:-1]
            # Add each attribute on a new line, indented
            for i, attr in enumerate(elem.attrib.items()):
                lines.insert(i+1, '  {}="{}"'.format(attr[0], attr[1]))
            # Rejoin the lines and replace the element text
            elem.text = '\n'.join(lines[1:])
            elem.tail = '\n'
    
    # Return the formatted XML as a string
    return ET.tostring(root, encoding='unicode', method='xml')

# with open('VariableLibrary.xml', 'r') as f:
#     xml_string = f.read()
#     print(format_xml(xml_string))

# print(format_xml_with_attributes_on_newline('VariableLibrary.xml'))

print(format_xml_file('VariableLibrary_raw.xml'))
# Out:
# <?xml version="1.0" ?>
# <VariableLibrary>
#
#
#     <IDFile path="Ark/ArkCameraShakes.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/ArkCameraShakes.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/ArkFactions.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/ArkFactions.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/ArkMetaTags.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/ArkMetaTags.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/ArkPropertyProfiles.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/ArkPropertyProfiles.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/ArkRewards.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/ArkRewards.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Attention/AttentionModels.xml" nameAttribute="name" idAttribute="id" variablePath="Ark.AttentionModels" xmlPath="AttentionModels"
#     path="Ark/Attention/AttentionModels.xml"
#     nameAttribute="name"
#     idAttribute="id"
#     variablePath="Ark.AttentionModels"
#     xmlPath="AttentionModels"/>
#
#
#     <IdFile path="Ark/Campaign/AudioLogs.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/AudioLogs.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/Books.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/Books.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/CharacterLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/CharacterLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/EmailLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/EmailLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/GameStateConditionLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/GameStateConditionLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/GroupLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/GroupLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/KeycardLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/KeycardLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/KeycodeLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/KeycodeLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/Locations.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/Locations.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/LoreLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/LoreLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/Notes.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/Notes.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/POILibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/POILibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/SecurityStationLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/SecurityStationLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/TutorialLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/TutorialLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Campaign/WorkstationLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Campaign/WorkstationLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/EmotionLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/EmotionLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/EntitlementLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/EntitlementLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/EntitlementUnlockLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/EntitlementUnlockLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/GameNoises.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/GameNoises.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Npc/NpcAbilities.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Npc/NpcAbilities.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Npc/NpcAbilityContextProfiles.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Npc/NpcAbilityContextProfiles.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Npc/NpcAbilityContexts.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Npc/NpcAbilityContexts.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Npc/NpcGameEffects.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Npc/NpcGameEffects.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/AbilitiesPDALayout.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/AbilitiesPDALayout.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/GameMetrics.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/GameMetrics.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/PlayerSignalReceiverConfig.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/PlayerSignalReceiverConfig.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/PsiScanningConfig.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/PsiScanningConfig.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/ResearchTopics.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/ResearchTopics.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/SignalFXLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/SignalFXLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/StatPackages.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/StatPackages.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/Player/Traumas.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/Player/Traumas.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/RemoteEventLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/RemoteEventLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/SignalSystem/Modifiers.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/SignalSystem/Modifiers.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/SignalSystem/Packages.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/SignalSystem/Packages.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/SignalSystem/SignalGroups.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/SignalSystem/SignalGroups.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/SignalSystem/Signals.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/SignalSystem/Signals.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/TipLibrary.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/TipLibrary.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/VisualEffects/CharacterAttachmentEffects.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/VisualEffects/CharacterAttachmentEffects.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/VisualEffects/MaterialAnimations.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/VisualEffects/MaterialAnimations.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Ark/WeaponMods/ArkWeaponMods.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Ark/WeaponMods/ArkWeaponMods.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkBreakableObjects.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkBreakableObjects.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkDestructibleLights.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkDestructibleLights.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkGameplayArchitecture.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkGameplayArchitecture.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkGameplayObjects.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkGameplayObjects.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkHumans.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkHumans.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkInteractiveProps.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkInteractiveProps.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkinteractivereadable.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkinteractivereadable.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkLights.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkLights.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arklights_signs.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arklights_signs.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkNpcs.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkNpcs.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkPhysicsProps.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkPhysicsProps.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkphysicstest.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkphysicstest.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkPickups.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkPickups.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkprojectiles.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkprojectiles.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkrobots.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkrobots.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkspecialweapons.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkspecialweapons.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/ArkSubObjectCollisionTest.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/ArkSubObjectCollisionTest.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/EntityArchetypes/arkutilities.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/EntityArchetypes/arkutilities.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/GT_GameTime.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/GT_GameTime.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/GT_Global.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/GT_Global.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/GT_GlobalStrings.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/GT_GlobalStrings.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/GT_selliott_test1.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/GT_selliott_test1.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/Lighting_debug.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/Lighting_debug.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/sallen_Test.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/sallen_Test.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/sshain_Test.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/sshain_Test.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/TestTokens.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/TestTokens.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/VS_Apex.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/VS_Apex.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
#     <IDFile path="Libs/GameTokens/VS_GameTokens.xml" nameAttribute="" idAttribute="" variablePath="" xmlPath=""
#     path="Libs/GameTokens/VS_GameTokens.xml"
#     nameAttribute=""
#     idAttribute=""
#     variablePath=""
#     xmlPath=""/>
#
#
# </VariableLibrary>
